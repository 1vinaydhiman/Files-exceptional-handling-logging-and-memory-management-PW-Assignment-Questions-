# %%
# Files, exceptional handling, logging and  memory management Questions Assignment PW.
#THEORITICAL QUESTIONS
#1. What is the difference between interpreted and compiled languages?
# --- Interpreted languages execute code line-by-line using an interpreter, making debugging easier but slower.
#     Compiled languages convert code into machine language before execution, offering faster performance. 
#     Python is interpreted, while C++ is compiled.

# %%
#2.What is exception handling in Python?
#---   Exception handling allows a program to respond to runtime errors gracefully.
#     Python uses `try`, `except`, `else`, and `finally` blocks to manage exceptions and prevent crashes.

# %%
#3. What is the purpose of the finally block in exception handling?
#---   The `finally` block runs regardless of whether an exception occurred. 
#      It is used for cleanup actions like closing files or releasing resources.

# %%
#4. What is logging in Python?
#---   Logging records events during program execution. Python’s `logging` module helps 
#      track errors, warnings, and info messages for debugging and monitoring.

# %%
#5.  What is the significance of the __del__ method in Python?
#---   The `__del__` method is a destructor called when an object is about to be destroyed.
#      It is used to release resources or perform cleanup tasks.

# %%
#6. What is the difference between import and from ... import in Python?
#--- `import module` loads the entire module, requiring prefixing with the module name.
#    `from module import function` imports specific functions or classes directly.

# %%
#7. How can you handle multiple exceptions in Python?
#---   Python allows handling multiple exceptions using multiple `except` blocks 
#    or combining them in a tuple: `except (TypeError, ValueError):`.

# %%
#8.  What is the purpose of the with statement when handling files in Python?
#--- The `with` statement ensures proper opening and closing of files.
#   It automatically handles resource cleanup, even if exceptions occur.

# %%
#9. What is the difference between multithreading and multiprocessing?
#--- Multithreading runs multiple threads in a single process, sharing memory.
#   Multiprocessing runs separate processes, offering better performance for CPU-bound tasks.

# %%
#10. What are the advantages of using logging in a program?
#---   Logging helps track program flow, errors, and performance. 
#  It improves debugging, maintains records, and supports monitoring in production environments.

# %%
#11.  What is memory management in Python?
#---   Python manages memory using private heap space and automatic garbage collection. 
#   Objects are stored in memory and cleaned up when no longer needed.

# %%
#12.  What are the basic steps involved in exception handling in Python?
#---  - Use `try` to wrap risky code  
#     - Use `except` to catch errors  
#     - Optionally use `else` for code that runs if no error occurs  
#     - Use `finally` for cleanup actions

# %%
#13.  Why is memory management important in Python
#--- Efficient memory management prevents memory leaks and ensures optimal performance.
#  Python’s garbage collector helps reclaim unused memory automatically.

# %%
#14.  What is the role of try and except in exception handling?
#---   The `try` block contains code that may raise an error. 
#   The `except` block catches and handles the error, preventing program termination.

# %%
#15. How does Python's garbage collection system work?
#---   Python uses reference counting and a cyclic garbage collector to manage memory.
#    It automatically deletes objects with zero references.

# %%
#16.  What is the purpose of the else block in exception handling?
#---    The `else` block runs only if no exception occurs in the `try` block. 
#   It is used for code that should execute when everything goes smoothly.

# %%
#17.  What are the common logging levels in Python?
#---Python’s logging levels are:  
#   - DEBUG: Detailed info  
#   - INFO: General events  
#   - WARNING: Potential issues  
#   - ERROR: Serious problems  
#   - CRITICAL: Severe errors

# %%
#18. What is the difference between os.fork() and multiprocessing in Python?
#---    `os.fork()` creates a child process in Unix systems.
#  The `multiprocessing` module is cross-platform and provides a higher-level API for process creation.

# %%
#19.  What is the importance of closing a file in Python?
#--- Closing a file releases system resources and ensures data is written properly. 
#  It prevents memory leaks and file corruption.

# %%
#20.  What is the difference between file.read() and file.readline() in Python?
#--- `file.read()` reads the entire file as a string. `file.readline()` reads one line at a time, 
#    useful for large files or line-by-line processing.

# %%
#21.  What is the logging module in Python used for?
#---   The `logging` module provides flexible logging capabilities.
#   It allows developers to record messages with different severity levels and output formats.

# %%
#22.  What is the os module in Python used for in file handling?
#--- The `os` module provides functions to interact with the operating system. 
#   It helps in file creation, deletion, path manipulation, and directory management.

# %%
#23.  What are the challenges associated with memory management in Python?
#---   Challenges include managing circular references, memory leaks, and optimizing performance.
#   Python’s garbage collector helps but may need manual tuning.

# %%
#24.  How do you raise an exception manually in Python?
#--- Use the `raise` keyword to trigger an exception manually.
#   Example: `raise ValueError("Invalid input")` stops execution and shows the error message.

# %%
#25.  Why is it important to use multithreading in certain applications?
#--- Multithreading improves performance in I/O-bound applications.
#  It allows concurrent execution, reducing wait times and enhancing responsiveness.

# %%
#PRACTICAL QUESTIONS 

#1.  How can you open a file for writing in Python and write a string to it
with open("test.txt", "w") as file:
    file.write("Hello, this is a string written to a file.")

# %%
#2. Write a Python program to read the contents of a file and print each line
with open("test.txt", "r") as file:
    for line in file:
        print(line.strip())
# Out:
# Hello, this is a string written to a file.

# %%
#3. How would you handle a case where the file doesn't exist while trying to open it for reading
try:
    with open("missing_file.txt", "r") as file:
        content = file.read()
except FileNotFoundError:
    print("Error: The file you are looking for does not exist.")
# Out:
# Error: The file you are looking for does not exist.

# %%
#4. Write a Python script that reads from one file and writes its content to another file
with open("source.txt", "w") as file:
    file.write("Hello, this is a string written to a file.")
with open("source.txt", "r") as src, open("destination.txt", "w") as dest:
    dest.write(src.read())

# %%
#5.How would you catch and handle division by zero error in Python
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero!")
# Out:
# Cannot divide by zero!

# %%
#6. Write a Python program that logs an error message to a log file when a division by zero exception occurs
import logging
logging.basicConfig(filename="app.log", level=logging.ERROR)

try:
    10 / 0
except ZeroDivisionError:
    logging.error("Attempted to divide by zero.")

# %%
#7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module
import logging
logging.basicConfig(level=logging.DEBUG)

logging.info("This is an informational message.")
logging.warning("This is a warning.")
logging.error("This is an error message.")

# %%
#8. Write a program to handle a file opening error using exception handling
try:
    f = open("restricted_file.txt", "r")
except IOError as e:
    print(f"Could not open file: {e}")
# Out:
# Could not open file: [Errno 2] No such file or directory: 'restricted_file.txt'

# %%
#9. How can you read a file line by line and store its content in a list in Python
with open("test.txt", "r") as file:
    lines_list = file.readlines() # or [line.strip() for line in file]

# %%
#10. How can you append data to an existing file in Python
with open("test.txt", "a") as file:
    file.write("\nThis line is appended.")

# %%
#11. Write a Python program that uses a try-except block to handle an error when attempting to access a 
my_dict = {"name": "Alice"}
try:
    print(my_dict["age"])
except KeyError:
    print("The key 'age' does not exist in the dictionary.")
# Out:
# The key 'age' does not exist in the dictionary.

# %%
#12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions
try:
    num = int(input("Enter a number: "))
    result = 100 / num
except ValueError:
    print("That's not a valid number!")
except ZeroDivisionError:
    print("You can't divide by zero!")
# Out:
# Enter a number:  55.5
# That's not a valid number!

# %%
#13. How would you check if a file exists before attempting to read it in Python
import os
if os.path.exists("test.txt"):
    print("File exists, proceeding to read...")
else:
    print("File not found.")
# Out:
# File exists, proceeding to read...

# %%
#14. Write a program that uses the logging module to log both informational and error messages
import logging
logging.basicConfig(level=logging.INFO)

logging.info("Process started.")
try:
    x = 1 / 0
except Exception as e:
    logging.error(f"An error occurred: {e}")

# %%
#15. Write a Python program that prints the content of a file and handles the case when the file is empty
import os
if os.path.getsize("test.txt") == 0:
    print("The file is empty.")
else:
    with open("test.txt", "r") as f:
        print(f.read())
# Out:
# Hello, this is a string written to a file.
# This line is appended.

# %%
#17. Write a Python program to create and write a list of numbers to a file, one number per line
nums = [10, 20, 30, 40]
with open("numbers.txt", "w") as f:
    for n in nums:
        f.write(f"{n}\n")

# %%
#18. How would you implement a basic logging setup that logs to a file with rotation after 1MB
import logging
from logging.handlers import RotatingFileHandler

handler = RotatingFileHandler("rotated.log", maxBytes=10**6, backupCount=3)
logging.basicConfig(handlers=[handler], level=logging.INFO)

# %%
#19. Write a program that handles both IndexError and KeyError using a try-except block
try:
    my_list = [1]
    my_dict = {"a": 1}
    # x = my_list[5] # Triggers IndexError
    # y = my_dict["b"] # Triggers KeyError
except (IndexError, KeyError) as e:
    print(f"Access error: {type(e).__name__}")

# %%
#20. How would you open a file and read its contents using a context manager in Python
# The 'with' keyword is the context manager
with open("test.txt", "r") as f:
    data = f.read()

# %%
#21. Write a Python program that reads a file and prints the number of occurrences of a specific word
word_to_find = "Python"
count = 0
with open("test.txt", "r") as f:
    for line in f:
        count += line.count(word_to_find)
print(f"Found {word_to_find} {count} times.")
# Out:
# Found Python 0 times.

# %%
#22. How can you check if a file is empty before attempting to read its contents
import os
if os.path.exists("test.txt") and os.path.getsize("test.txt") > 0:
    # Read file
    pass

# %%
#23. Write a Python program that writes to a log file when an error occurs during file handling.
import logging
logging.basicConfig(filename="file_errors.log", level=logging.ERROR)

try:
    with open("non_existent.txt", "r") as f:
        data = f.read()
except IOError as e:
    logging.error(f"File handling failed: {e}")
